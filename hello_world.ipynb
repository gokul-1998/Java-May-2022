// %% [markdown]
// ## Step 3: Verify Output
// The output above shows 'Hello World!' which confirms the program executed successfully. You now have a working Java notebook with mixed markdown and code cells!

// %% [markdown]
// ## Step 2: Print Hello World
// Execute the code cell below to print 'Hello World' to the output.

// %%
System.out.println("Hello World!");
// Out:
// Hello World!

// %% [markdown]
// ## Step 1: Import Required Libraries
// No special imports are needed for this basic program.

// %% [markdown]
// # Hello World in Java
// This notebook demonstrates a simple Hello World program in Java using Jupyter.
